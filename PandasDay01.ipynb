# %% [markdown]
# <a href="https://colab.research.google.com/github/GautamChy/Data-Science-Journey/blob/main/PandasDay01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series([10,20,30,40]) # left side ko columm ma  index and right side ko column ma  value hunxa.
print(s)                     # dtype means value haru ko data. i.e 64bit ko integer chha it means.
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
s = pd.Series([10,20,30], index= ["a","b","c"]) # aafai ley index pani haalna milyo
print(s)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
s.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
s.values
# Out:
# array([10, 20, 30])

# %%
s['b']
# Out:
# np.int64(20)

# %%
s['c']
# Out:
# np.int64(30)

# %% [markdown]
# # DataFrame
# - dherai ota Data haru vayo vanney DataFrame vanna milxa.
# - 2D is a DataFrame but not 1D
# - NOTE: 1D vanney ko Series and 2D  vanney ko DataFrame
# - NOTE: Dictionary ma key and value jastai garney BUT key represent garxa column DataFrame ma.

# %%
df = pd.DataFrame({
    'name' : ['Ramesh', 'Rajesh', 'Rabin'],  # name is column, Ramesh,Rajesh,Rabin is value of the column
    'age'  : [25,30,40],
    'salary' : [30000, 400000,70000]
})

print(df)                          # 0,1,2, output is an index.
# Out:
#      name  age  salary
# 0  Ramesh   25   30000
# 1  Rajesh   30  400000
# 2   Rabin   40   70000

# %% [markdown]
# # CSV = It means comma seperated values
# - df = pd.read_csv("file vitra ko data name")
#   - df.head()

# %%
df = pd.read_csv("google_stock_price.csv")
df.head()
# Out:
#          Date     Price
# 0  2004-08-19  2.490664
# 1  2004-08-20  2.515820
# 2  2004-08-23  2.758411
# 3  2004-08-24  2.770615
# 4  2004-08-25  2.614201

# %% [markdown]
# Excel file read garna lai.
# - df = pd.read_excel
#
# json file read garna lai
# - df = pd.read_json

# %%
df = pd.read_csv("pokemon.csv")
df.head()
# Out:
#          Name           Type
# 0   Bulbasaur  Grass, Poison
# 1     Ivysaur  Grass, Poison
# 2    Venusaur  Grass, Poison
# 3  Charmander           Fire
# 4  Charmeleon           Fire

# %%
df = pd.read_csv("revenue.csv")
df.head()
# Out:
#      Date  New York  Los Angeles  Miami
# 0  1/1/26       985          122    499
# 1  1/2/26       738          788    534
# 2  1/3/26        14           20    933
# 3  1/4/26       730          904    885
# 4  1/5/26       114           71    253

# %% [markdown]
# # shape = how much row and how much column

# %%
df.shape # 10 rows and 4 columns
# Out:
# (10, 4)

# %% [markdown]
# # dtypes = columns haru ko datatype

# %%
df.dtypes

# %% [markdown]
# # head() = top 5 from upper

# %%
df.head()
# Out:
#      Date  New York  Los Angeles  Miami
# 0  1/1/26       985          122    499
# 1  1/2/26       738          788    534
# 2  1/3/26        14           20    933
# 3  1/4/26       730          904    885
# 4  1/5/26       114           71    253

# %% [markdown]
# # tail() = top 5 from buttom

# %%
df.tail()
# Out:
#       Date  New York  Los Angeles  Miami
# 5   1/6/26       936          502    497
# 6   1/7/26       123          996    115
# 7   1/8/26       935          492    886
# 8   1/9/26       846          954    823
# 9  1/10/26        54          285    216

# %% [markdown]
# # info() = dataset ko information haru.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         10 non-null     object
#  1   New York     10 non-null     int64
#  2   Los Angeles  10 non-null     int64
#  3   Miami        10 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 452.0+ bytes

# %% [markdown]
# # describe =  Nemeric column  haru ko lagi descriptive state output ma dinxa.

# %%
df.describe()

# %%
df
# Out:
#       Date  New York  Los Angeles  Miami
# 0   1/1/26       985          122    499
# 1   1/2/26       738          788    534
# 2   1/3/26        14           20    933
# 3   1/4/26       730          904    885
# 4   1/5/26       114           71    253
# 5   1/6/26       936          502    497
# 6   1/7/26       123          996    115
# 7   1/8/26       935          492    886
# 8   1/9/26       846          954    823
# 9  1/10/26        54          285    216

# %% [markdown]
# # df[' ' ] = specific column herna lai

# %%
df['New York']
# Out:
# 0    985
# 1    738
# 2     14
# 3    730
# 4    114
# 5    936
# 6    123
# 7    935
# 8    846
# 9     54
# Name: New York, dtype: int64

# %% [markdown]
# # df [[" " , " "]]  = 2 ota column herna lai

# %%
df [['New York' , 'Miami']]
# Out:
#    New York  Miami
# 0       985    499
# 1       738    534
# 2        14    933
# 3       730    885
# 4       114    253
# 5       936    497
# 6       123    115
# 7       935    886
# 8       846    823
# 9        54    216

# %%
df
# Out:
#       Date  New York  Los Angeles  Miami
# 0   1/1/26       985          122    499
# 1   1/2/26       738          788    534
# 2   1/3/26        14           20    933
# 3   1/4/26       730          904    885
# 4   1/5/26       114           71    253
# 5   1/6/26       936          502    497
# 6   1/7/26       123          996    115
# 7   1/8/26       935          492    886
# 8   1/9/26       846          954    823
# 9  1/10/26        54          285    216

# %% [markdown]
# # iloc[] = which position access

# %%
df.iloc[0]  # first row ko value access, o is the index

# %%
df.iloc[-1] # last row ko value access, -1 is the index
# Out:
# Date           1/10/26
# New York            54
# Los Angeles        285
# Miami              216
# Name: 9, dtype: object

# %%
df.iloc[0:3] # access from 0 to 3 value. 0 is the index and 3 is the index. Ending samma acccess hudoina. i.e 0 to 2 samma matra access hunxa.

# %%
df.iloc[0,1] # 0 ma vako row and 1 ma vako column.If comma aaunxa vaney i.e 0,1 it means find row and column
# Out:
# np.int64(985)

# %%
df
# Out:
#       Date  New York  Los Angeles  Miami
# 0   1/1/26       985          122    499
# 1   1/2/26       738          788    534
# 2   1/3/26        14           20    933
# 3   1/4/26       730          904    885
# 4   1/5/26       114           71    253
# 5   1/6/26       936          502    497
# 6   1/7/26       123          996    115
# 7   1/8/26       935          492    886
# 8   1/9/26       846          954    823
# 9  1/10/26        54          285    216

# %%
df.loc[0]
# Out:
# Date           1/1/26
# New York          985
# Los Angeles       122
# Miami             499
# Name: 0, dtype: object

# %% [markdown]
# # loc = position access, loc means location. It access from start to end. i.e 0 to 3 samma.

# %%
df.loc[0:3] # ending samma acccess hunxa.i.e 0 to 3 samma.

# %% [markdown]
# # sample : Everytime print random sample

# %%
df.sample()
# Out:
#      Date  New York  Los Angeles  Miami
# 0  1/1/26       985          122    499

# %%
df
# Out:
#       Date  New York  Los Angeles  Miami
# 0   1/1/26       985          122    499
# 1   1/2/26       738          788    534
# 2   1/3/26        14           20    933
# 3   1/4/26       730          904    885
# 4   1/5/26       114           71    253
# 5   1/6/26       936          502    497
# 6   1/7/26       123          996    115
# 7   1/8/26       935          492    886
# 8   1/9/26       846          954    823
# 9  1/10/26        54          285    216

# %%
df.loc[0, 'New York']  # 0 row ko New York column
# Out:
# np.int64(985)

# %%
df.loc[0:2, "New York":"Miami"] # 0 deko 2 samma ko row and New York and Miami ko column.
# Out:
#    New York  Los Angeles  Miami
# 0       985          122    499
# 1       738          788    534
# 2        14           20    933

# %% [markdown]
# # filter

# %%
df
# Out:
#       Date  New York  Los Angeles  Miami
# 0   1/1/26       985          122    499
# 1   1/2/26       738          788    534
# 2   1/3/26        14           20    933
# 3   1/4/26       730          904    885
# 4   1/5/26       114           71    253
# 5   1/6/26       936          502    497
# 6   1/7/26       123          996    115
# 7   1/8/26       935          492    886
# 8   1/9/26       846          954    823
# 9  1/10/26        54          285    216

# %%
df[df['New York'] > 800] # New York column ko 800 vanda greater value only give.

# %% [markdown]
# # & ()
# - AND

# %%
df [(df["New York"] > 800) & (df["Miami"] > 500) ]  # New York column ko 800 vanda greater AND Miami column ko 500 vanda greater value give.
# Out:
#      Date  New York  Los Angeles  Miami
# 7  1/8/26       935          492    886
# 8  1/9/26       846          954    823

# %% [markdown]
# #  |
# - OR
# - OR means athwa bujhney, Yo value deu navaye yo value deu.

# %%
df[(df["New York"] > 800) | (df["Miami"] > 500)] # # New York column ko 800 vanda greater OR Miami column ko 500 vanda greater value hunnu paryo.
# Out:
#      Date  New York  Los Angeles  Miami
# 0  1/1/26       985          122    499
# 1  1/2/26       738          788    534
# 2  1/3/26        14           20    933
# 3  1/4/26       730          904    885
# 5  1/6/26       936          502    497
# 7  1/8/26       935          492    886
# 8  1/9/26       846          954    823

# %% [markdown]
# # head() = It gives only Top 5 value from up.

# %%
df1 = pd.read_csv('pokemon.csv')
df1.head()
# Out:
#          Name           Type
# 0   Bulbasaur  Grass, Poison
# 1     Ivysaur  Grass, Poison
# 2    Venusaur  Grass, Poison
# 3  Charmander           Fire
# 4  Charmeleon           Fire

# %% [markdown]
# # isin()

# %%
df1[df1['Name'].isin(["Bulbasaur", "Ivysaur", "Pikachu"])]

# %%
df = pd.DataFrame({
    'name' : ['Ramesh', 'Rajesh', 'Rabin'],  # name is column, Ramesh,Rajesh,Rabin is value of the column
    'age'  : [25,30,40],
    'salary' : [30000, 400000,70000]
})

print(df)

# %%
df[df['name'].isin(["Rabin", "Rajesh"])]
# Out:
#      name  age  salary
# 1  Rajesh   30  400000
# 2   Rabin   40   70000

# %%
df[df['salary'].isin(["Rajesh"])]
# Out:
# Empty DataFrame
# Columns: [name, age, salary]
# Index: []

# %%
df[df['age'].isin(['Rajesh','Rabin'])]
# Out:
# Empty DataFrame
# Columns: [name, age, salary]
# Index: []

# %%
df[df['salary'] > 40000]
# Out:
#      name  age  salary
# 1  Rajesh   30  400000
# 2   Rabin   40   70000

# %%
df[(df["salary"] > 4000) & (df["age"] > 20) ]
# Out:
#      name  age  salary
# 0  Ramesh   25   30000
# 1  Rajesh   30  400000
# 2   Rabin   40   70000

# %%
df
# Out:
#      name  age  salary
# 0  Ramesh   25   30000
# 1  Rajesh   30  400000
# 2   Rabin   40   70000

# %% [markdown]
# # Added new column
# - df['new column name'] = df['old column'] +,-,*,/
#    - df.head()

# %%
df['bonus'] = df['salary'] * 0.1       # bonus vaney column add garey and salary sitaw multiplication 0.1 garey.
df.head()

# %% [markdown]
# # modify old column

# %%
df

# %%
df['age'] = df['age'] +1  # age ma 1 value add garda old ma 29 new ma 30
df.head()
# Out:
#      name  age  salary    bonus
# 0  Ramesh   26   30000   3000.0
# 1  Rajesh   31  400000  40000.0
# 2   Rabin   41   70000   7000.0

# %%
df['senior'] = df['age'] > 30 # Adding senior column if age greater than 30 then True
df.head()
# Out:
#      name  age  salary    bonus  senior
# 0  Ramesh   26   30000   3000.0   False
# 1  Rajesh   31  400000  40000.0    True
# 2   Rabin   41   70000   7000.0    True

# %% [markdown]
# # isnull().sum() : It show how much missing value left
# - kati ota missing value khali chha.

# %%
df.isnull().sum()    # here kunai column ma pani missing value xoina, 0 means no missing value.
# Out:
# name      0
# age       0
# salary    0
# bonus     0
# senior    0
# dtype: int64

# %% [markdown]
# # dropna()
# - if missing value chha vanney.

# %%
df.dropna()
# Out:
#      name  age  salary    bonus  senior
# 0  Ramesh   26   30000   3000.0   False
# 1  Rajesh   31  400000  40000.0    True
# 2   Rabin   41   70000   7000.0    True

# %% [markdown]
# # dropna(subset = [' ' ] )
# - if kunai column ma missing value chha vanney tyo chai hateraw jaanchha.

# %%
df.dropna(subset=['age'])   # ailey kunai missing value aako xoina ,if chha vanney matra aaunxa.
# Out:
#      name  age  salary    bonus  senior
# 0  Ramesh   26   30000   3000.0   False
# 1  Rajesh   31  400000  40000.0    True
# 2   Rabin   41   70000   7000.0    True

# %% [markdown]
# # fillna(0) = missing value ko thau ma 0 lageyraw fill gardinxa.

# %%
df.fillna(0) # missing value xoina so 0 katai fill vayena
# Out:
#      name  age  salary    bonus  senior
# 0  Ramesh   26   30000   3000.0   False
# 1  Rajesh   31  400000  40000.0    True
# 2   Rabin   41   70000   7000.0    True

# %% [markdown]
# # STATISTICS

# %% [markdown]
# # df['column name'].fillna(df['column name'].mean())
# -  specific column ma pani missing value fill garney tarika.

# %%
df['age'].fillna(df['age'].mean()) # yeha missing value xoina So jey chha original tyestai aayo.
# Out:
# 0    26
# 1    31
# 2    41
# Name: age, dtype: int64

# %%
df
# Out:
#      name  age  salary    bonus  senior
# 0  Ramesh   26   30000   3000.0   False
# 1  Rajesh   31  400000  40000.0    True
# 2   Rabin   41   70000   7000.0    True

# %% [markdown]
# # Mean = finding average
# - df[' column name' ] .mean()

# %%
df['salary'].mean()
# Out:
# np.float64(166666.66666666666)

# %%
df['age'].mean()
# Out:
# np.float64(32.666666666666664)

# %% [markdown]
# # Median
# - df[' column name' ].median()

# %%
df['salary'].median()
# Out:
# 70000.0

# %%
df['age'].median()
# Out:
# 31.0

# %% [markdown]
# # standard deviation
# - df['column name '].std()

# %%
df['salary'].std()
# Out:
# 203059.92547357376

# %% [markdown]
# # min() = minimum value
# - df['column name'].min()

# %%
df['salary'].min()
# Out:
# 30000

# %% [markdown]
# # max() = maximum value
# - df['column'].max()

# %%
df['salary'].max()
# Out:
# 400000

# %% [markdown]
# # value_counts() = It counts the value how many times repeat.
# - kati ota value and kati choti repeat vachha counts garchha.
# - df['column name'].value_counts()

# %%
df['salary'].value_counts() # salary ko value kati choti repeat vaako chha.
# Out:
# salary
# 30000     1
# 400000    1
# 70000     1
# Name: count, dtype: int64

# %%
df.sort_values('salary')
# Out:
#      name  age  salary    bonus  senior
# 0  Ramesh   26   30000   3000.0   False
# 2   Rabin   41   70000   7000.0    True
# 1  Rajesh   31  400000  40000.0    True

# %% [markdown]
# # sort_values = ascending order ma value lai sort gardinxa.
# - df.sort_values('column name')

# %%
df  # origina data
# Out:
#      name  age  salary    bonus  senior
# 0  Ramesh   26   30000   3000.0   False
# 1  Rajesh   31  400000  40000.0    True
# 2   Rabin   41   70000   7000.0    True

# %%
df.sort_values('salary')
# Out:
#      name  age  salary    bonus  senior
# 0  Ramesh   26   30000   3000.0   False
# 2   Rabin   41   70000   7000.0    True
# 1  Rajesh   31  400000  40000.0    True

# %% [markdown]
# # To make descending order

# %%
df.sort_values('salary', ascending=False)
# Out:
#      name  age  salary    bonus  senior
# 1  Rajesh   31  400000  40000.0    True
# 2   Rabin   41   70000   7000.0    True
# 0  Ramesh   26   30000   3000.0   False

# %%
df
# Out:
#      name  age  salary    bonus  senior
# 0  Ramesh   26   30000   3000.0   False
# 1  Rajesh   31  400000  40000.0    True
# 2   Rabin   41   70000   7000.0    True

# %%
df.sort_values(['senior', 'age'])
# Out:
#      name  age  salary    bonus  senior
# 0  Ramesh   26   30000   3000.0   False
# 1  Rajesh   31  400000  40000.0    True
# 2   Rabin   41   70000   7000.0    True

# %% [markdown]
# # rename
# - df.rename(columns = {'original column name' : 'new column name' }

# %%
df.rename(columns = {'name':'Full Name', 'age':'years'}, inplace = True)
df.head()
# Out:
#   Full Name  years  salary    bonus  senior
# 0    Ramesh     26   30000   3000.0   False
# 1    Rajesh     31  400000  40000.0    True
# 2     Rabin     41   70000   7000.0    True

# %% [markdown]
# # drop = To delete the column
# - df.drop(columns = ['columm name'])

# %%
df.drop(columns = ['senior'])
# Out:
#   Full Name  years  salary    bonus
# 0    Ramesh     26   30000   3000.0
# 1    Rajesh     31  400000  40000.0
# 2     Rabin     41   70000   7000.0

# %%
df.head()
# Out:
#   Full Name  years  salary    bonus  senior
# 0    Ramesh     26   30000   3000.0   False
# 1    Rajesh     31  400000  40000.0    True
# 2     Rabin     41   70000   7000.0    True

# %% [markdown]
# # To drop the row

# %%
df.drop(index=[0,1])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-299/4259117582.py in <cell line: 0>()
# ----> 1 df.drop(index=[0,1])
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
df
# Out:
#   Full Name  years  salary   bonus  senior
# 2     Rabin     41   70000  7000.0    True

# %%
df.head()
# Out:
#   Full Name  years  salary   bonus  senior
# 2     Rabin     41   70000  7000.0    True

# %% [markdown]
# # To save the file as new

# %%
df.to_csv("Output.csv", index = False)  # file ma yo name save hunchha.

# %%
df.to_excel("Output.xlsx", index=False)

# %%
df = pd.read_csv('employees.csv')
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.dtypes
# Out:
# First Name            object
# Gender                object
# Start Date            object
# Last Login Time       object
# Salary                 int64
# Bonus %              float64
# Senior Management     object
# Team                  object
# dtype: object

# %% [markdown]
# # isnull() = It check kati ota mah khaali xa value.
# - counting for each column how many null values there produce a new dataframe which display the sum of isnull

# %%
df.isnull().sum()
# Out:
# First Name            67
# Gender               145
# Start Date             0
# Last Login Time        0
# Salary                 0
# Bonus %                0
# Senior Management     67
# Team                  43
# dtype: int64

# %%
df.dropna(subset = ['First Name'], inplace = True) # First Name ko missing value haru lai hataidinxa.

# %%
df.isnull().sum()
# Out:
# First Name             0
# Gender               138
# Start Date             0
# Last Login Time        0
# Salary                 0
# Bonus %                0
# Senior Management      0
# Team                  34
# dtype: int64

# %%
df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %% [markdown]
# # high earners

# %%
high_earners = df[df['Salary'] > 100000]
high_earners
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 5       Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 9      Frances  Female    8/8/2002         6:51 AM  139852    7.524
# ..         ...     ...         ...             ...     ...      ...
# 990      Robin  Female   7/24/1987         1:35 PM  100765   10.982
# 991       Rose  Female   8/25/2002         5:12 AM  134505   11.051
# 992    Anthony    Male  10/16/2011         8:35 AM  112769   11.625
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 2               False               Finance
# 3                True               Finance
# ...

# %%
df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %% [markdown]
# # groupby()
# - high_earners.groupby(" column ko department name or team name ')['Column name kun ko'].mean()

# %%
# Find the average salary of the team.
high_earners.groupby("Team")['Salary'].mean()
# Out:
# Team
# Business Development    122922.022222
# Client Services         120210.179487
# Distribution            123275.851852
# Engineering             124238.317073
# Finance                 129043.974359
# Human Resources         122308.714286
# Legal                   124497.323529
# Marketing               126258.432432
# Product                 120951.142857
# Sales                   124939.558824
# Name: Salary, dtype: float64

# %%
# Make it in descending order
high_earners.groupby("Team")['Salary'].mean().sort_values(ascending=False)
# Out:
# Team
# Finance                 129043.974359
# Marketing               126258.432432
# Sales                   124939.558824
# Legal                   124497.323529
# Engineering             124238.317073
# Distribution            123275.851852
# Business Development    122922.022222
# Human Resources         122308.714286
# Product                 120951.142857
# Client Services         120210.179487
# Name: Salary, dtype: float64
