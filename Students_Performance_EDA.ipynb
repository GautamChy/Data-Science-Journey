# %% [markdown]
# <a href="https://colab.research.google.com/github/GautamChy/Data-Science-Journey/blob/main/Students_Performance_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EDA Student Performance Indicator

# %% [markdown]
# 1. Problem Statement

# %% [markdown]
# * This project understands how the student's performance (test scores) is affected by other variables such as Gender, Ethnicity, Parental level of education, Lunch and Test preparation course.

# %% [markdown]
# 2. Data Collection

# %% [markdown]
# * Dataset Source : https://www.kaggle.com/datasets/spscientist/students-performance-in-exams
# * The data consists of 8 columns and 1000 rows.

# %% [markdown]
# 3. Dataset Information

# %% [markdown]
# * gender : ->(Male/female)
# * race/ethnicity : ethnicity of students -> (Group A,B,C,D,E)
# * parental level of education : parent's final education -> (bachelor's degree, some college, master's degree, associate's degree, high school)
# * lunch : having lunch before test(standard or free/reduced)
# * test preparation course : complete or not complete before test
# * math score
# * reading score
# * writing score

# %% [markdown]
# Step 1 : Import all the required libraries

# %%
# Importing all the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Step 2 : Read the dataset

# %%
# loading the dataset
df = pd.read_csv('stud.csv')
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.shape
# Out:
# (1000, 8)

# %% [markdown]
# Data Checks to Perform
#
# * Check Missing values
# * Check Duplicates
# * Check data type
# * Check the number of unique values of each column
# * Check statistics of dataset
# * Check various categories present in different categorical column

# %% [markdown]
# Check Missing values

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df.isna().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df.notna().sum()
# Out:
# gender                         1000
# race/ethnicity                 1000
# parental level of education    1000
# lunch                          1000
# test preparation course        1000
# math score                     1000
# reading score                  1000
# writing score                  1000
# dtype: int64

# %% [markdown]
# Insight or Observation
# * There are no missing values.

# %% [markdown]
# Check Duplicates

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %% [markdown]
# counting duplicated

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Insight or Observation
# * There are no duplicate values in the dataset

# %% [markdown]
# Check data type

# %%
df.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %% [markdown]
# Checking inforamtion of Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# describing of the dataset

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# Check the number of unique values of each column

# %%
df.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64

# %% [markdown]
# Check the number of unique values of race/ethnicity column

# %%
df['race/ethnicity'].unique()
# Out:
# array(['group B', 'group C', 'group A', 'group D', 'group E'],
#       dtype=object)

# %% [markdown]
# counting the unique value of race/ethnicity column

# %%
df['race/ethnicity'].nunique()
# Out:
# 5

# %% [markdown]
# Check the number of unique values of lunch column

# %%
df['lunch'].unique()
# Out:
# array(['standard', 'free/reduced'], dtype=object)

# %% [markdown]
# counting the unique value of lunch column

# %%
df['lunch'].nunique()
# Out:
# 2

# %%
df['gender'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %% [markdown]
# Describing all column

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# Observation:
#
# * From the above description of numerical data, all means are very close to each other - between 66.054 and 69.169.
# * All the standard deviation are also close - between 14.6 and 15.19.
# * While there is a minimum of 0 for maths, other are having 17 and 10 value.

# %% [markdown]
# Checking 05 rows from top

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# checking 100 rows

# %%
df.head(100)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 2   female        group B             master's degree      standard
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# ..     ...            ...                         ...           ...
# 95    male        group C          associate's degree  free/reduced
# 96    male        group B            some high school      standard
# 97  female        group E                some college      standard
# 98  female        group D                some college  free/reduced
# 99  female        group D           bachelor's degree      standard
#
#    test preparation course  math score  reading score  writing score
# 0                     none          72             72             74
# ...

# %% [markdown]
# Checking  05 rows from buttom

# %%
df.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %% [markdown]
# checking 100 row from buttom

# %%
df.tail(100)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 900    male        group D             master's degree      standard
# 901  female        group C             master's degree      standard
# 902  female        group A                 high school  free/reduced
# 903  female        group D           bachelor's degree  free/reduced
# 904  female        group D            some high school  free/reduced
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# checking all columns name

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %% [markdown]
# checking the list of rows labels

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %% [markdown]
# checking data inside the dataFrame as a Numpy

# %%
df.values
# Out:
# array([['female', 'group B', "bachelor's degree", ..., 72, 72, 74],
#        ['female', 'group C', 'some college', ..., 69, 90, 88],
#        ['female', 'group B', "master's degree", ..., 90, 95, 93],
#        ...,
#        ['female', 'group C', 'high school', ..., 59, 71, 65],
#        ['female', 'group D', 'some college', ..., 68, 78, 77],
#        ['female', 'group D', 'some college', ..., 77, 86, 86]],
#       dtype=object)

# %% [markdown]
# creating list of all columns

# %%
list(df.columns)
# Out:
# ['gender',
#  'race/ethnicity',
#  'parental level of education',
#  'lunch',
#  'test preparation course',
#  'math score',
#  'reading score',
#  'writing score']

# %% [markdown]
# checking each column data type

# %%
df['gender'].dtype
# Out:
# dtype('O')

# %%
df['lunch'].dtype
# Out:
# dtype('O')

# %% [markdown]
# Count how many times each unique value appears in the gender column

# %%
df['gender'].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
518/(518+482) * 100
# Out:
# 51.800000000000004

# %%
482/(518+482) * 100
# Out:
# 48.199999999999996

# %% [markdown]
# Observation
#
# * The dataset is balanced in the gender column.

# %% [markdown]
# # Visualization

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score  average_score
# 0          218      72.666667
# 1          247      82.333333
# 2          278      92.666667
# ...

# %%
df['total_score'] = df['math score'] + df['reading score'] + df['writing score']
df['average_score'] = df['total_score'] / 3

# %%
print(df['total_score'])
# Out:
# 0      218
# 1      247
# 2      278
# 3      148
# 4      229
#       ...
# 995    282
# 996    172
# 997    195
# 998    223
# 999    249
# Name: total_score, Length: 1000, dtype: int64

# %%
print(df['average_score'])
# Out:
# 0      72.666667
# 1      82.333333
# 2      92.666667
# 3      49.333333
# 4      76.333333
#          ...
# 995    94.000000
# 996    57.333333
# 997    65.000000
# 998    74.333333
# 999    83.000000
# Name: average_score, Length: 1000, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.subplots(1,2, figsize = (11,7)) # 1 row and 2 colums, 11 inch wide and 7 inch tall
plt.subplot(1,2,1)  # Create a layout of 1 row and 2 columns, and activate the first plot (left side)
sns.histplot(data=df, x = 'average_score', bins = 40, kde = True, color = 'g')
plt.subplot(1,2,2) #(nrows, ncols, index),Create a layout of 1 row and 2 columns, and select the second plot (right side)
sns.histplot(data=df, x = 'average_score',  bins = 40, kde = True, hue = 'gender')
plt.show()

# %% [markdown]
# Insights
#
# Female students tends to perform well than male students

# %%
plt.subplots(1, 3, figsize = (14, 4)) # 1 row and 3 colums, 14 inch wide and 4 inch tall
plt.subplot(131) # Create a layout of 1 row and 3 columns, and activate the first plot (left side)
sns.histplot(data = df, x = 'average_score', kde = True, hue = 'lunch')
plt.subplot(132) # Create a layout of 1 row and 3 columns, and activate the second plot (middle side)
sns.histplot(data = df[df['gender'] == 'female'], x = 'average_score', kde = True, hue = 'lunch')
plt.subplot(133) # Create a layout of 1 row and 3 columns, and activate the third plot (last plot)
sns.histplot(data = df[df['gender'] == 'male'], x = 'average_score', kde = True, hue = 'lunch')
plt.show()

# %% [markdown]
# #Insights
#
# * Standard Lunch help students perform well in exams.
# * Standard lunch helps perform well in exams be it a male or female.

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score  average_score
# 0          218      72.666667
# 1          247      82.333333
# 2          278      92.666667
# ...

# %%
plt.subplots(1, 3, figsize = (25, 6))
plt.subplot(131)
sns.histplot(data = df, x = 'average_score', kde = True, hue = 'parental level of education')
plt.subplot(132)
sns.histplot(data = df[df['gender'] == 'female'], x = 'average_score', kde = True, hue = 'parental level of education')
plt.subplot(133)
sns.histplot(data = df[df['gender'] == 'male'], x = 'average_score', kde = True, hue = 'parental level of education')
plt.show()

# %% [markdown]
# Observation :
#
# * In general parent's education don't help student perform well in exam.
# * 3rd plot shows that parents whose education is of associate degree or master's degree their male child tend to perform well in exam.
# * 2nd plot shows that there is no effect of parent's education on female students.
