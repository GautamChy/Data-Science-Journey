# %% [markdown]
# <a href="https://colab.research.google.com/github/GautamChy/Data-Science-Journey/blob/main/task09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - Write a Python function using def to return the product of any count of numbers that is passed as an argument to the function.

# %%
# 1. Product of any count of numbers
def product(*args):
    result = 1
    for num in args:
        result *= num
    return result

# %% [markdown]
# - Create a function that takes a string and returns its length.

# %%
# 2. Function that returns length of a string
def string_length(s):
    return len(s)

# %% [markdown]
# - Write a function that checks if a given number is divisible by 7 or not.

# %%
# 3. Check if number is divisible by 7
def is_divisible_by_7(num):
    return num % 7 == 0

# %% [markdown]
# - Use map() to square only even numbers in a list [1, 2, 3, 4, 5].

# %%
# 5. Square only even numbers
numbers = [1, 2, 3, 4, 5]
squared_evens = list(map(lambda x: x**2, filter(lambda x: x % 2 == 0, numbers)))
print(squared_evens)
# Out:
# [4, 16]

# %% [markdown]
# - Use filter() to extract even numbers from a list [1, 2, 3, 4, 5, 6, 7, 8].

# %%
# 6. Extract even numbers
nums = [1, 2, 3, 4, 5, 6, 7, 8]
even_numbers = list(filter(lambda x: x % 2 == 0, nums))
print(even_numbers)
# Out:
# [2, 4, 6, 8]

# %% [markdown]
# - Use reduce() from functools to calculate the product of a list [1, 2, 3, 4, 5].

# %%
# 7. Product of a list using reduce
from functools import reduce

lst = [1, 2, 3, 4, 5]
product_result = reduce(lambda x, y: x * y, lst)
print(product_result)
# Out:
# 120

# %% [markdown]
# - Convert a list of strings to uppercase using map().

# %%
# 8. Convert list of strings to uppercase
words = ["apple", "banana", "cherry"]
uppercase_words = list(map(lambda x: x.upper(), words))
print(uppercase_words)
# Out:
# ['APPLE', 'BANANA', 'CHERRY']

# %% [markdown]
# - Use filter() to get all words with length greater than 3 from ["hi", "hello", "world", "yes"].

# %%
# 9. Words with length > 3
words = ["hi", "hello", "world", "yes"]
long_words = list(filter(lambda x: len(x) > 3, words))
print(long_words)
# Out:
# ['hello', 'world']

# %% [markdown]
# - Write a lambda function to add 10 to a given number.

# %%
# 10. Add 10 to a number
add_ten = lambda x: x + 10

# %% [markdown]
# - Create a lambda function that returns the cube of a number.

# %%
# 11. Cube of a number
cube = lambda x: x ** 3

# %% [markdown]
# - Write a lambda function to check if a number is divisible by 9

# %%
# 12. Check divisibility by 9
divisible_by_9 = lambda x: x % 9 == 0

# %% [markdown]
# - Use a lambda function with map() to double each element in [2, 4, 6, 8].

# %%
# 13. Double each element
lst = [2, 4, 6, 8]
doubled = list(map(lambda x: x * 2, lst))
print(doubled)
# Out:
# [4, 8, 12, 16]

# %% [markdown]
# - Use a lambda function with filter() to get numbers greater than 5 from [1, 4, 6, 7, 9].

# %%
# 14. Numbers greater than 5
lst = [1, 4, 6, 7, 9]
greater_than_5 = list(filter(lambda x: x > 5, lst))
print(greater_than_5)
# Out:
# [6, 7, 9]

# %% [markdown]
# - Create a class Mobile with attributes brand and model, and a method to display them.

# %%
# 15. Mobile class
class Mobile:
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model

    def display(self):
        print(self.brand, self.model)

# %% [markdown]
# - Define a class Student with name and age attributes and a method to print them.

# %%
# 16. Student class
class Student:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def display(self):
        print(self.name, self.age)

# %% [markdown]
# - Create a class Rectangle with a method to calculate the area.

# %%
# 17. Rectangle area
class Rectangle:
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

# %% [markdown]
# - Implement a Person class with a private variable __salary and a method to get its value.

# %%
# 18. Private variable example
class Person:
    def __init__(self, salary):
        self.__salary = salary

    def get_salary(self):
        return self.__salary

# %% [markdown]
# - Create two different classes with a method describe(), then call the method on objects of both classes.

# %%
# 19. Two classes with same method name
class Dog:
    def describe(self):
        print("I am a dog")

class Cat:
    def describe(self):
        print("I am a cat")

Dog().describe()
Cat().describe()
# Out:
# I am a dog
# I am a cat

# %% [markdown]
# - Create a class Person with attributes name and age, and a method to display the information.

# %%
# 20. Person class with name and age
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def display(self):
        print(self.name, self.age)

# %% [markdown]
# - Write a function that takes different objects (Rectangle, Circle, Square) and calls their area() method.

# %%
# 21. Polymorphism with area()
class Circle:
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14 * self.radius ** 2

class Square:
    def __init__(self, side):
        self.side = side

    def area(self):
        return self.side ** 2

def print_area(shape):
    print(shape.area())

# %% [markdown]
# - Define a class Book with title and author attributes and a method to display book details.

# %%
# 22. Book class
class Book:
    def __init__(self, title, author):
        self.title = title
        self.author = author

    def display(self):
        print(self.title, self.author)

# %% [markdown]
# - Implement a class Calculator with methods for addition, subtraction, multiplication, and division.

# %%
# 23. Calculator class
class Calculator:
    def add(self, a, b):
        return a + b

    def subtract(self, a, b):
        return a - b

    def multiply(self, a, b):
        return a * b

    def divide(self, a, b):
        return a / b

# %% [markdown]
# - Use the ABC module to define an abstract class Shape with an abstract method calculate_area() and implement it in Circle and Rectangle subclasses.

# %%
# 24. Abstract class Shape
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def calculate_area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def calculate_area(self):
        return 3.14 * self.radius ** 2

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def calculate_area(self):
        return self.length * self.width

# %% [markdown]
# - Write a program to create a text file and write "Hello, Python!" into it, then read the content from the file.

# %%
# 25. Write and read a text file
with open("sample.txt", "w") as file:
    file.write("Hello, Python!")

with open("sample.txt", "r") as file:
    print(file.read())
# Out:
# Hello, Python!

# %% [markdown]
# - Implement a try-except-finally block where the finally statement prints
# - "Execution completed" after the exception handling.

# %%
# 26. try-except-finally
try:
    x = int("abc")
except ValueError:
    print("ValueError occurred")
finally:
    print("Execution completed")
# Out:
# ValueError occurred
# Execution completed

# %% [markdown]
# - Implement a function that raises a CustomException when the user enters a odd number the exception is raised.

# %%
# 27. Custom Exception for odd number
class CustomException(Exception):
    pass

def check_even(num):
    if num % 2 != 0:
        raise CustomException("Odd number entered")
    return "Even number"

# %% [markdown]
# - Write a program that takes two numbers and divides them, handling the case where the denominator is zero using try-except.

# %%
# 28. Division with zero handling
try:
    a = int(input("Enter numerator: "))
    b = int(input("Enter denominator: "))
    result = a / b
    print("Result:", result)
except ZeroDivisionError:
    print("Error: Division by zero is not allowed")
except ValueError:
    print("Invalid input")
# Out:
# Enter numerator: 2
# Enter denominator: 3
# Result: 0.6666666666666666
